# %% [markdown]
# # Sentiment Analysis Testing
#
# Test different sentiment analysis approaches on WSB posts.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

# %% [markdown]
# ## VADER Sentiment Analysis

# %%
# Initialize VADER
analyzer = SentimentIntensityAnalyzer()

# Test on sample WSB posts
sample_posts = [
    "GME to the moon! 🚀🚀🚀 Diamond hands!",
    "This stock is trash, selling all my puts",
    "YOLO'd my entire portfolio into NVDA calls"
]

for post in sample_posts:
    scores = analyzer.polarity_scores(post)
    print(f"Post: {post}")
    print(f"Scores: {scores}\n")

# %% [markdown]
# ## FinBERT Sentiment Analysis

# %%
# FinBERT implementation will go here
